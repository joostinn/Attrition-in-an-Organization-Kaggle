# %%
# Assistant
import numpy as np
import pandas as pd

from scipy.stats import skew

from sklearn.model_selection import KFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.ensemble import StackingRegressor
from sklearn.metrics import mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.inspection import permutation_importance


df_HR = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 23>()
#      19 from catboost import CatBoostRegressor
#      20 from sklearn.inspection import permutation_importance
# ---> 23 df_HR = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
#
# File /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# # Assistant
# This error occurs because the code is trying to read a CSV file that doesn't exist in your current working directory.
#
# The error message `FileNotFoundError [Errno 2] No such file or directory: 'WA_Fn-UseC_-HR-Employee-Attrition.csv'` indicates that Python cannot find the file "WA_Fn-UseC_-HR-Employee-Attrition.csv" in the location where your code is running.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # Assistant
# This error occurs because the code is trying to read a CSV file that doesn't exist in your current working directory.
#
# The error message `FileNotFoundError [Errno 2] No such file or directory: 'WA_Fn-UseC_-HR-Employee-Attrition.csv'` indicates that Python cannot find the file "WA_Fn-UseC_-HR-Employee-Attrition.csv" in the location where your code is running.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # User
# yes
